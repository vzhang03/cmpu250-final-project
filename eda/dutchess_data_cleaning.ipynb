# %% [markdown]
# **Initial Data Cleaning**

# %%
import pandas as pd

# %%
nys_data_raw = pd.read_csv("/Users/elliekogan/Documents/GitHub/cmpu250-final-project/data/raw-data/ny_home_purchase.csv")
# Out:
# /var/folders/qz/pmy_02y95f9bnkfj0nt_jdx40000gn/T/ipykernel_13926/3028005800.py:1: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   nys_data_raw = pd.read_csv("/Users/elliekogan/Documents/GitHub/cmpu250-final-project/data/raw-data/ny_home_purchase.csv")

# %%
nys_data_raw.head()
# Out:
#    activity_year                   lei  derived_msa-md state_code  \
# 0           2023  549300JOT0D4J0SZIK67           10580         NY
# 1           2023  549300JOT0D4J0SZIK67           15380         NY
# 2           2023  549300JOT0D4J0SZIK67           35614         NY
# 3           2023  549300JOT0D4J0SZIK67           40380         NY
# 4           2023  549300JOT0D4J0SZIK67           99999         NY
#
#    county_code  census_tract conforming_loan_limit derived_loan_product_type  \
# 0      36001.0  3.600101e+10                     C             VA:First Lien
# 1      36063.0  3.606302e+10                     C             VA:First Lien
# 2      36081.0  3.608103e+10                     C            FHA:First Lien
# 3      36055.0  3.605501e+10                     C   Conventional:First Lien
# 4      36039.0  3.603908e+10                     C            FHA:First Lien
#
#                 derived_dwelling_category        derived_ethnicity  ...  \
# 0    Single Family (1-4 Units):Site-Built  Ethnicity Not Available  ...
# 1    Single Family (1-4 Units):Site-Built  Ethnicity Not Available  ...
# 2    Single Family (1-4 Units):Site-Built  Ethnicity Not Available  ...
# 3    Single Family (1-4 Units):Site-Built  Ethnicity Not Available  ...
# 4  Single Family (1-4 Units):Manufactured  Ethnicity Not Available  ...
#
#   denial_reason-2 denial_reason-3  denial_reason-4  tract_population  \
# 0             NaN             NaN              NaN              5959
# 1             NaN             NaN              NaN              5709
# 2             NaN             NaN              NaN              7365
# 3             NaN             NaN              NaN              5281
# 4             NaN             NaN              NaN              4049
#
#    tract_minority_population_percent  ffiec_msa_md_median_family_income  \
# 0                              15.66                             113300
# 1                              17.46                              93900
# 2                              98.52                              99300
# 3                               8.45                              97300
# 4                              15.73                              83700
#
#    tract_to_msa_income_percentage  tract_owner_occupied_units  \
# 0                          143.60                        1516
# 1                           68.53                        1871
# 2                          102.77                        1466
# 3                          121.93                        1890
# 4                          125.59                        1426
#
#    tract_one_to_four_family_homes  tract_median_age_of_housing_units
# 0                            2219                                 51
# 1                            2154                                 47
# 2                            2172                                 67
# 3                            2336                                 52
# 4                            2286                                 53
#
# [5 rows x 99 columns]

# %% [markdown]
# **Variables to keep and clean:**
# - action_taken
# - derived_race
# - derived_ethnicity
# - applicant_sex
# - applicant_age
# - income
# - debt_to_income_ratio
# - applicant_credit_score_type
# - loan_amount
# - loan_to_value_ratio
# - interest_rate
# - rate_spread
# - loan_type
# - loan_purpose
# - lien_status
# - property_value
# - occupancy_type
# - tract_minority_population_percent
# - aus-1
# - denial_reason-1

# %%
nys_data = nys_data_raw[['action_taken', 'derived_race', 'derived_ethnicity', 'applicant_sex', 'applicant_age', 'income', 'debt_to_income_ratio', 'applicant_credit_score_type', 'loan_amount', 'loan_to_value_ratio', 'interest_rate', 'rate_spread', 'loan_type', 'loan_purpose', 'lien_status', 'property_value', 'occupancy_type', 'tract_minority_population_percent', 'aus-1', 'denial_reason-1']]

# %%
nys_data.head()
# Out:
#    action_taken        derived_race        derived_ethnicity  applicant_sex  \
# 0             6  Race Not Available  Ethnicity Not Available              4
# 1             6  Race Not Available  Ethnicity Not Available              4
# 2             6  Race Not Available  Ethnicity Not Available              4
# 3             6  Race Not Available  Ethnicity Not Available              4
# 4             6  Race Not Available  Ethnicity Not Available              4
#
#   applicant_age  income debt_to_income_ratio  applicant_credit_score_type  \
# 0          8888     NaN                  NaN                            9
# 1          8888     NaN                  NaN                            9
# 2          8888     NaN                  NaN                            9
# 3          8888     NaN                  NaN                            9
# 4          8888     NaN                  NaN                            9
#
#    loan_amount loan_to_value_ratio interest_rate rate_spread  loan_type  \
# 0     305000.0                 NaN           5.5         NaN          3
# 1     215000.0                 NaN         5.625         NaN          3
# 2     735000.0                 NaN          5.25         NaN          2
# 3     195000.0                 NaN         6.125         NaN          1
# 4     215000.0                 NaN          6.25         NaN          2
#
#    loan_purpose  lien_status property_value  occupancy_type  \
# 0             1            1         305000               1
# 1             1            1         215000               1
# 2             1            1         745000               1
# 3             1            1         215000               1
# 4             1            1         215000               1
#
#    tract_minority_population_percent  aus-1  denial_reason-1
# 0                              15.66      6               10
# 1                              17.46      6               10
# 2                              98.52      6               10
# 3                               8.45      6               10
# 4                              15.73      6               10
