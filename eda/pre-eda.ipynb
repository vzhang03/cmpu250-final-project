# %% [markdown]
# # Pre-EDA
#
# Short analysis prior to meeting splitting up EDA.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.style.use('classic')

# %%
df_original = pd.read_csv("../data/raw-data/dutchess_home_purchase.csv")
df = df_original.copy()

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3823 entries, 0 to 3822
# Data columns (total 99 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   activity_year                             3823 non-null   int64
#  1   lei                                       3823 non-null   object
#  2   derived_msa-md                            3823 non-null   int64
#  3   state_code                                3819 non-null   object
#  4   county_code                               3823 non-null   int64
#  5   census_tract                              3812 non-null   float64
#  6   conforming_loan_limit                     3806 non-null   object
#  7   derived_loan_product_type                 3823 non-null   object
#  8   derived_dwelling_category                 3823 non-null   object
#  9   derived_ethnicity                         3823 non-null   object
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of       activity_year                   lei  derived_msa-md state_code  \
# 0              2023  254900FBWEZ3YUPOBN33           39100         NY
# 1              2023  254900FBWEZ3YUPOBN33           39100         NY
# 2              2023  549300NZ2IPWRMLAYZ30           39100         NY
# 3              2023  549300NZ2IPWRMLAYZ30           39100         NY
# 4              2023  549300NZ2IPWRMLAYZ30           39100         NY
# ...             ...                   ...             ...        ...
# 3818           2023  2549002VH9C0PKB8K153           39100         NY
# 3819           2023  2549002VH9C0PKB8K153           39100         NY
# 3820           2023  549300LR1ZETOWYE9Z89           39100         NY
# 3821           2023  549300LR1ZETOWYE9Z89           39100         NY
# 3822           2023  254900EZRN0CBEP77K34           39100         NY
#
#       county_code  census_tract conforming_loan_limit  \
# ...

# %%
df.columns
# Out:
# Index(['activity_year', 'lei', 'derived_msa-md', 'state_code', 'county_code',
#        'census_tract', 'conforming_loan_limit', 'derived_loan_product_type',
#        'derived_dwelling_category', 'derived_ethnicity', 'derived_race',
#        'derived_sex', 'action_taken', 'purchaser_type', 'preapproval',
#        'loan_type', 'loan_purpose', 'lien_status', 'reverse_mortgage',
#        'open-end_line_of_credit', 'business_or_commercial_purpose',
#        'loan_amount', 'loan_to_value_ratio', 'interest_rate', 'rate_spread',
#        'hoepa_status', 'total_loan_costs', 'total_points_and_fees',
#        'origination_charges', 'discount_points', 'lender_credits', 'loan_term',
#        'prepayment_penalty_term', 'intro_rate_period', 'negative_amortization',
#        'interest_only_payment', 'balloon_payment',
#        'other_nonamortizing_features', 'property_value', 'construction_method',
#        'occupancy_type', 'manufactured_home_secured_property_type',
# ...

# %% [markdown]
# ## Trying to understand financial outcome variables and financial predictor variables

# %%
df.iloc[:, :20].head(10)
# Out:
#    activity_year                   lei  derived_msa-md state_code  \
# 0           2023  254900FBWEZ3YUPOBN33           39100         NY
# 1           2023  254900FBWEZ3YUPOBN33           39100         NY
# 2           2023  549300NZ2IPWRMLAYZ30           39100         NY
# 3           2023  549300NZ2IPWRMLAYZ30           39100         NY
# 4           2023  549300NZ2IPWRMLAYZ30           39100         NY
# 5           2023  549300NZ2IPWRMLAYZ30           39100         NY
# 6           2023  549300NZ2IPWRMLAYZ30           39100         NY
# 7           2023  549300NZ2IPWRMLAYZ30           39100         NY
# 8           2023  549300NZ2IPWRMLAYZ30           39100         NY
# 9           2023  549300NZ2IPWRMLAYZ30           39100         NY
#
#    county_code  census_tract conforming_loan_limit derived_loan_product_type  \
# 0        36027  3.602701e+10                     C   Conventional:First Lien
# 1        36027  3.602704e+10                     C   Conventional:First Lien
# ...

# %%
df.iloc[:, 20:40].head(10)
# Out:
#    business_or_commercial_purpose  loan_amount loan_to_value_ratio  \
# 0                               1     295000.0              63.183
# 1                               1     455000.0                65.0
# 2                               2     395000.0                96.5
# 3                               2     255000.0                96.5
# 4                               2     275000.0               100.0
# 5                               2     455000.0              96.999
# 6                               2     405000.0              82.425
# 7                               2     385000.0              96.499
# 8                               2     275000.0                 NaN
# 9                               2     305000.0                80.0
#
#   interest_rate rate_spread  hoepa_status total_loan_costs  \
# 0         11.55         NaN             3              NaN
# 1         11.75         NaN             3              NaN
# ...

# %%
df.iloc[:, 40:60].head(10)
# Out:
#    occupancy_type  manufactured_home_secured_property_type  \
# 0               3                                        3
# 1               3                                        3
# 2               1                                        3
# 3               1                                        3
# 4               1                                        1
# 5               1                                        3
# 6               1                                        3
# 7               1                                        3
# 8               1                                        3
# 9               1                                        3
#
#    manufactured_home_land_property_interest total_units  \
# 0                                         5           1
# 1                                         5           1
# 2                                         5           2
# 3                                         5           1
# ...

# %%
df.iloc[:, 60:80].head(10)
# Out:
#    co-applicant_ethnicity_observed  applicant_race-1  applicant_race-2  \
# 0                                3               7.0               NaN
# 1                                3               7.0               NaN
# 2                                4               3.0               NaN
# 3                                4               5.0               NaN
# 4                                4               6.0               NaN
# 5                                4               5.0               NaN
# 6                                2               5.0               NaN
# 7                                2               6.0               NaN
# 8                                2               5.0               NaN
# 9                                2               5.0               NaN
#
#    applicant_race-3  applicant_race-4  applicant_race-5  co-applicant_race-1  \
# 0               NaN               NaN               NaN                    7
# ...

# %%
df.iloc[:, 80:100].head(10)
# Out:
#   co-applicant_age_above_62  submission_of_application  \
# 0                       NaN                          1
# 1                       NaN                          1
# 2                       NaN                          1
# 3                       NaN                          1
# 4                       NaN                          1
# 5                       NaN                          1
# 6                        No                          1
# 7                        No                          1
# 8                        No                          1
# 9                        No                          1
#
#    initially_payable_to_institution  aus-1  aus-2  aus-3  aus-4  aus-5  \
# 0                                 1      6    NaN    NaN    NaN    NaN
# 1                                 1      6    NaN    NaN    NaN    NaN
# 2                                 1      3    NaN    NaN    NaN    NaN
# 3                                 1      3    NaN    NaN    NaN    NaN
# ...

# %%
loan_details = ["conforming_loan_limit", "derived_loan_product_type", "business_or_commercial_purpose",  "loan_amount", "loan_to_value_ratio", "interest_rate", "rate_spread", "hoepa_status",
    "total_loan_costs", "total_points_and_fees", "origination_charges", "discount_points",
    "lender_credits", "loan_term", "prepayment_penalty_term", "intro_rate_period",
    "negative_amortization", "interest_only_payment", "balloon_payment",
    "other_nonamortizing_features", "loan_type",	"loan_purpose", "submission_of_application", "submission_of_application"
]

# %%
action_details = ["action_taken",	"purchaser_type",	"preapproval","lien_status",	"reverse_mortgage", "denial_reason-1", "denial_reason-2", "denial_reason-3", "denial_reason-4",
                      "aus-1", "aus-2", "aus-3", "aus-4", "aus-5"
                   ]

# %%
person_details = ["open-end_line_of_credit", "income", "debt_to_income_ratio", "applicant_credit_score_type", "co-applicant_credit_score_type"]

# %%
# werid variable 
other = ["property_value"]

# %% [markdown]
# ## Testing Memory Usage and Speed of Large dataset

# %%
full_df = pd.read_csv("../data/raw-data/ny_home_purchase.csv")
# Out:
# /var/folders/ks/s_c55z9517dglyh1tf2y9rhh0000gn/T/ipykernel_39335/2149263200.py:1: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   full_df = pd.read_csv("../data/raw-data/ny_home_purchase.csv")

# %%
full_df['aus-1'].unique()
# Out:
# array([   6,    3,    1,    2, 1111,    7,    4,    5])

# %%
full_df['aus-1'] = full_df['aus-1'].replace(1111, -1)

# %%
full_df.hist("aus-1", bins=range(full_df["aus-1"].min(), full_df["aus-1"].max() + 2))

plt.title("Figure 1: Result of Automated System for NY State")
plt.xlabel("Reason")
plt.ylabel("Count")
plt.show()
